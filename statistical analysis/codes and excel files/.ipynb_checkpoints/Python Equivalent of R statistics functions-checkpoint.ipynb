# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Probability Density Function usage or dnorm()

# %%
mean = 0
sd = 10
x = np.arange(-100,100,0.5)
y = norm.pdf(x,loc=mean, scale=sd)
plt.plot(x,y,'-')

# %% [markdown]
# # Cumulative Density Function or pnorm()

# %%
number = -10
prob = norm.cdf(number,loc=mean, scale=sd)
print(prob)
plt.plot(x,y,'-')
plt.fill_between(x[x<=number],y[x<=number],color='red')
# Out:
# 0.15865525393145707

# %% [markdown]
# # Complementary CDF or pnorm(lower.tail = FALSE)

# %%
number = -10
prob = norm.sf(number,loc=mean, scale=sd)
print(prob)
plt.plot(x,y,'-')
plt.fill_between(x[x>=number],y[x>=number],color='red')
# Out:
# 0.8413447460685429

# %% [markdown]
# # Percentile point function or qnorm()

# %%
probability = 0.15865525393145707
number = norm.ppf(probability,loc=mean,scale=sd)
print(number)
# Out:
# -10.0

# %% [markdown]
# # Inverse Survival Function or qnorm(lower.tail = False)

# %%
probability = 0.8413447460685429
number = norm.isf(probability,loc=mean,scale=sd)
print(number)
# Out:
# -10.0
